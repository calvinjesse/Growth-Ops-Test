# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns

# %%
data = pd.read_excel(r'/content/drive/MyDrive/Dataset/growth_assignment_data.xlsx')
df = pd.DataFrame(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
print(df.shape)
print(df.head(15))
# Out:
# (3210, 5)
#          Date  # of Orders Status of Order    Total CBV Service
# 0  2016-01-01        180.0       Cancelled   76076000.0  GO-BOX
# 1  2016-01-02        210.0       Cancelled   92423695.0  GO-BOX
# 2  2016-01-03        230.0       Cancelled  104029380.0  GO-BOX
# 3  2016-01-04        250.0       Cancelled  107114280.0  GO-BOX
# 4  2016-01-05        210.0       Cancelled   90296570.0  GO-BOX
# 5  2016-01-06        190.0       Cancelled   74894820.0  GO-BOX
# 6  2016-01-07        200.0       Cancelled   83905185.0  GO-BOX
# 7  2016-01-08        300.0       Cancelled  123198530.0  GO-BOX
# 8  2016-01-09        320.0       Cancelled  142122890.0  GO-BOX
# 9  2016-01-10        250.0       Cancelled  108576650.0  GO-BOX
# 10 2016-01-11        280.0       Cancelled  143598000.0  GO-BOX
# 11 2016-01-12        320.0       Cancelled  152468225.0  GO-BOX
# 12 2016-01-13        290.0       Cancelled  135244655.0  GO-BOX
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3210 entries, 0 to 3209
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             3210 non-null   datetime64[ns]
#  1   # of Orders      3210 non-null   float64
#  2   Status of Order  3210 non-null   object
#  3   Total CBV        3210 non-null   float64
#  4   Service          3210 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 125.5+ KB

# %%
df.columns = df.columns.str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3210 entries, 0 to 3209
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             3210 non-null   datetime64[ns]
#  1   # of Orders      3210 non-null   float64
#  2   Status of Order  3210 non-null   object
#  3   Total CBV        3210 non-null   float64
#  4   Service          3210 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 125.5+ KB

# %%
df1 = df.rename({'Date' : 'date', '# of Orders' : 'num_of_order', 'Status of Order' : 'status', 'Total CBV' : 'total_cbv', 'Service' : 'service'},axis=1)

# %%
df1['month']=pd.DatetimeIndex(df1['date']).month
df1.head()
# Out:
#         date  num_of_order     status    total_cbv service  month
# 0 2016-01-01         180.0  Cancelled   76076000.0  GO-BOX      1
# 1 2016-01-02         210.0  Cancelled   92423695.0  GO-BOX      1
# 2 2016-01-03         230.0  Cancelled  104029380.0  GO-BOX      1
# 3 2016-01-04         250.0  Cancelled  107114280.0  GO-BOX      1
# 4 2016-01-05         210.0  Cancelled   90296570.0  GO-BOX      1

# %%
pivot = df1.pivot_table(index=['service','status'],values=['num_of_order'],columns=['month'],aggfunc='sum',fill_value = 0,margins=True,margins_name = 'grand_total')

# %%
pivot
# Out:
#                             num_of_order                              \
# month                                  1         2         3       4
# service     status
# GO-BOX      Cancelled               8710      8920     11910     430
#             Completed              19310     19390     25060    1270
#             No Driver Found         1200      1020      1230      60
#             Other                      0         0         0       0
# GO-CLEAN    Cancelled                420       510       770      40
#             Completed               4190      3930      6160     230
#             No Driver Found           80       150       370      10
#             Other                     20       470       180       0
# GO-FOOD     Cancelled            1032510    542270    443540   15610
#             Completed            2328700   2068690   2242370   75240
#             No Driver Found        15610     13200     10210     240
# ...
